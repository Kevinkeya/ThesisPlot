# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pylab as plt

# %%
Cosine_outerlier_distance=[1, 0.9681, 0.662, 0.0406, 0.915, 0.6212, 0.5545, 0.9771, 0, 0.9652, 0.927, 0.9355, 0.9699, 0.7655]
Jaccard_outlier_distance=[1, 0.9691, 0.7141, 0.4448, 0.8843, 0.6677, 0.5868, 0.9686, 0, 0.7746333333, 0.8876, 0.8858, 0.9465, 0.872]
Pearson_outlier_distance=[1.0004, 0.9686, 0.6673, 0.0407, 0.9261, 0.6305, 0.5652, 0.9805, 0, 0.96, 0.9286, 0.9369, 0.9706, 0.7668]
sns_three_color = ["windows blue","dusty purple","faded green"]
sns_palette = [sns.xkcd_rgb[color__] for color__ in sns_six_color]
labels = ['Cosine', 'Jaccard', 'Pearson']
plt.figure(figsize=(8,8), dpi=200)
sns.boxplot(data=[Cosine_outerlier_distance,Jaccard_outlier_distance,Pearson_outlier_distance], palette=sns_palette )
sns.swarmplot(data=[Cosine_outerlier_distance,Jaccard_outlier_distance,Pearson_outlier_distance],color=".3")
plt.ylabel('Distance')
plt.xlabel('Metric')
plt.xticks([0,1,2], labels)
plt.savefig("output/" +"outlier_metric_distance.png")

# %%
Cosine_12_5 = [0.002895413587, 0.004098302497, 0.08005437162, 0.1578414802, 0.01673796926, 0.115904139, 0.01799789112,
               0.03631700017, 0.01234678169, 0.09939383629, 0.02562698704, 0.03507419201, 0.01772660357]
Cosine_25 = [0.05131670195, 0.01248526281, 0.1089933791, 0.2287337407, 0.1285398675, 0.2490682378, 0.1147738327,
             0.0627981222, 0.04601983869, 0.1567877839, 0.053796052, 0.05639297615, 0.1220914612]
Cosine_50 = [0.08809373047, 0.06557418177, 0.1835034191, 0.3693795397, 0.2364063311, 0.451451998, 0.1897218188,
             0.09164035728, 0.07891010679, 0.2910641564, 0.07477874846, 0.07679440471, 0.2310002293]
Cosine_75 = [0.1875604076, 0.1165504687, 0.2734571691, 0.7166812368, 0.3795701301, 0.7870164562, 0.3108791571,
             0.1466152329, 0.1267199352, 0.4887079205, 0.1133537775, 0.1163995938, 0.4031055963]
Cosine_87_5 = [0.2964578882, 0.1639658422, 0.3592841618, 0.9415345182, 0.6765944722, 1, 0.6275855079, 0.2045455565,
               0.1912997196, 0.6456338067, 0.1570526721, 0.1562784572, 0.7899508224]
Jaccard_12_5 = [0.1111111111, 0.09431166508, 0.1854761074, 0.3462418181, 0.211649763, 0.3184617344, 0.2005919919,
                0.09985171329, 0.08902024457, 0.2445373577, 0.1039056021, 0.1052169525, 0.2260755995]
Jaccard_25 = [0.125, 0.1168668974, 0.2446183106, 0.3862918969, 0.3250160143, 0.4061992705, 0.2540296092, 0.1354935008,
              0.1138517786, 0.3276613635, 0.1192525259, 0.1240254159, 0.2928013908]
Jaccard_50 = [0.2025818349, 0.154841485, 0.3367835058, 0.5418933007, 0.4010787216, 0.7196434149, 0.3381023265, 0.1875,
              0.1681573022, 0.4571029518, 0.1520570897, 0.1538065841, 0.4330578486]
Jaccard_75 = [0.3491164805, 0.224183675, 0.4345845686, 0.8418959871, 0.5310432425, 0.8979155574, 0.5, 0.2752634058,
              0.2459508858, 0.6121906014, 0.2102467376, 0.2163484461, 0.619047254]
Jaccard_87_5 = [0.5, 0.3004740487, 0.5256635689, 0.9462997657, 0.7616672821, 1, 0.7340917416, 0.3597488348,
                0.3438668383, 0.7594518922, 0.2907653655, 0.2789842168, 0.8588001925]
Pearson_12_5 = [0.0145339378, 0.004716114196, 0.04575879722, 0.1091798771, 0.01055401631, 0.03410871147, 0.004820830339,
                0.03285242712, 0.01152802039, 0.1059729106, 0.02750207908, 2.22E-16, 0.0002244908203]
Pearson_25 = [0.05582980348, 0.01308478777, 0.1065454139, 0.2198682597, 0.115142454, 0.1537222213, 0.1072781518,
              0.06010296848, 0.04622334584, 0.1682349087, 0.05522494733, 0.05253783042, 0.08847167555]
Pearson_50 = [0.08838409356, 0.06760698189, 0.1807598598, 0.3651147552, 0.2352282723, 0.3638544136, 0.187811651,
              0.09083790709, 0.07935119833, 0.2926641024, 0.07543256118, 0.07617704137, 0.2256758501]
Pearson_75 = [0.1920605741, 0.118816545, 0.2737238539, 0.7003123374, 0.3575978742, 0.8007376833, 0.3063085774,
              0.1470217515, 0.1271576412, 0.4933542921, 0.1137832236, 0.1160408425, 0.3634083058]
Pearson_87_5 = [0.3012582518, 0.1688110109, 0.3584420462, 0.9473881133, 0.6778675037, 1.008928571, 0.6276227157,
                0.2052626299, 0.1920759614, 0.6480011077, 0.1581195636, 0.1554782992, 0.7880181288]
plt.figure(figsize=(12,8), dpi=200)
Cosine_percentile = [Cosine_12_5, Cosine_25 ,Cosine_50, Cosine_75, Cosine_87_5]
Jaccard_percentile = [Jaccard_12_5,Jaccard_25,Jaccard_50,Jaccard_75, Jaccard_87_5]
Pearson_percentile = [Pearson_12_5,Pearson_25,Pearson_50, Pearson_75, Pearson_87_5]
# sns.boxplot(data=[Cosine_12_5, Jaccard_12_5,Pearson_12_5], positions = [1, 3], palette = sns_palette)
# 
ax = plt.axes()
sns.boxplot(data=[Cosine_12_5, Jaccard_12_5,Pearson_12_5]\
            +[Cosine_25,Jaccard_25,Pearson_25]\
            +[Cosine_50,Jaccard_50,Pearson_50]\
            +[Cosine_75,Jaccard_75,Pearson_75]\
            +[Cosine_87_5,Jaccard_87_5,Pearson_87_5],\
            palette = sns_palette)

sns.swarmplot(data=[Cosine_12_5, Jaccard_12_5,Pearson_12_5]\
            +[Cosine_25,Jaccard_25,Pearson_25]\
            +[Cosine_50,Jaccard_50,Pearson_50]\
            +[Cosine_75,Jaccard_75,Pearson_75]\
            +[Cosine_87_5,Jaccard_87_5,Pearson_87_5],\
            color=".3")

ax.set_xticklabels(['12.5', '25', '50','75','87.5'])
ax.set_xticks([1, 4, 7,10,13])
hB, = plt.plot([1,1],sns_palette[0])
hR, = plt.plot([1,1],sns_palette[1])
hY, = plt.plot([1,1],sns_palette[2])
plt.legend((hB, hR, hY),('Cosine', 'Jaccard','Pearson'))
hB.set_visible(False)
hR.set_visible(False)
hY.set_visible(False)
plt.ylabel('Distance')
plt.xlabel('Percentile')
# Out:
# Text(0.5,0,'Percentile')
